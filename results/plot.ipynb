# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import numpy as np

# %%
cut=10000
maxent_norevisit_test=np.load('./active_no_revisit/test_accuracy_list.npy')[0:cut]
maxent_norevisit_train=np.load('./active_no_revisit/train_accuracy_list.npy')[0:cut]
maxent_revisit_test=np.load('./active_revisit/test_accuracy_list.npy')[0:cut]
maxent_revisit_train=np.load('./active_revisit/train_accuracy_list.npy')[0:cut]
random1_test=np.load('./random/test_accuracy_list.npy')[0:cut]
random1_train=np.load('./random/train_accuracy_list.npy')[0:cut]
random2_test=np.load('./random2/test_accuracy_list.npy')[0:cut]
random2_train=np.load('./random2/train_accuracy_list.npy')[0:cut]
maxent_revisit_mc10_test=np.load('./grad_mc_10/test_accuracy_list.npy')[0:cut]
maxent_revisit_mc10_train=np.load('./grad_mc_10/train_accuracy_list.npy')[0:cut]
maxent_revisit_q50_test=np.load('./q50/test_accuracy_list.npy')[0:cut]
maxent_revisit_q50_train=np.load('./q50/train_accuracy_list.npy')[0:cut]
maxent_revisit_q100_test=np.load('./q100/test_accuracy_list.npy')[0:cut]
maxent_revisit_q100_train=np.load('./q100/train_accuracy_list.npy')[0:cut]
maxent_revisit_q200_test=np.load('./q200/test_accuracy_list.npy')[0:cut]
maxent_revisit_q200_train=np.load('./q200/train_accuracy_list.npy')[0:cut]
maxent_revisit_q50_vs_data=np.load('./q50/test_accuracy_vs_data.npy')[0:cut]

maxent_revisit_500_test=np.load('./500it/test_accuracy_list.npy')[0:cut]
maxent_revisit_500_train=np.load('./500it/train_accuracy_list.npy')[0:cut]

maxent_revisit_mc5_test=np.load('./mc5/test_accuracy_list.npy')[0:cut]
maxent_revisit_mc5_train=np.load('./mc5/train_accuracy_list.npy')[0:cut]
maxent_revisit_mc5_vs_data=np.load('./mc5/test_accuracy_vs_data.npy')[0:cut]

maxent_norevisit_mc5_test=np.load('./mc5_norevisit/test_accuracy_list.npy')[0:cut]
maxent_norevisit_mc5_train=np.load('./mc5_norevisit/train_accuracy_list.npy')[0:cut]


sns.set(style="whitegrid")
plt.title('test accuracy')
#plt.plot(random_test,label='random1')
plt.plot(random2_test,label='random2')
#plt.plot(maxent_norevisit_test,label='maxent_norevisit')
# plt.plot(maxent_revisit_mc5_test,label='maxent_mc5_revisit')
plt.plot(maxent_revisit_mc5_vs_data,label='maxent_mc5_revisit_vs_data')
plt.plot(maxent_norevisit_mc5_test,label='maxent_mc5_norevisit')
# plt.plot(maxent_revisit_test,label='maxent_revisit')
# plt.plot(maxent_revisit_mc10_test,label='maxent_mc10_revisit')
# plt.plot(maxent_revisit_500_test,label='maxent_500_revisit')
# plt.plot(maxent_revisit_q50_test,label='maxent_q50_revisit')
# plt.plot(maxent_revisit_q50_vs_data,label='maxent_q50_revisit_vs_data')

plt.ylim([0.7,1.0])
plt.legend(loc='lower right')
plt.axhline(y=0.9607264995574951, color='r', linestyle='-')
plt.show()

plt.title('train accuracy')
#plt.plot(random1_train,label='random1')
plt.plot(random2_train,label='random2')
# plt.plot(maxent_norevisit_train,label='maxent_norevisit')
#plt.plot(maxent_revisit_train,label='maxent_revisit')
# plt.plot(maxent_revisit_mc10_train,label='maxent_mc10_revisit')
# plt.plot(maxent_revisit_500_train,label='maxent_500_revisit')
# plt.plot(maxent_revisit_q50_train,label='maxent_q50_revisit')
plt.plot(maxent_revisit_mc5_train,label='maxent_mc5_revisit')
plt.plot(maxent_norevisit_mc5_train,label='maxent_mc5_norevisit')

plt.legend(loc='lower left')
plt.show()
